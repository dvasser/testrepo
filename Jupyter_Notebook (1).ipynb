# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## __Daniel Vasserman__
# Striving Data Scientist

# %% [markdown]
# _I am planning to become a Data Scientist because I have great interest towards finding algorithms in how the world works._

# %% [markdown]
# ### My code is supposed to write "I like Statistics"

# %%
print("I like statistics")
# Out:
# I like statistics

# %% [markdown]
# _Data Science is the Sexiest Job in the 21st Century_
# ***
# | Occupation | Platform | Tool |
# | --- | --- | --- |
# | Data Science | IBM | Watson Studio |
#
# - Data Analyst
# - Data Engineer
# - Data Scientist

# %% [markdown]
# ![bgd br.png](attachment:6a7f85ae-a4c6-404d-8c46-e6f3eef089a7.png)
